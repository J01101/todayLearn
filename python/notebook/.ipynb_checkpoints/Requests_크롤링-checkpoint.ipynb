# %%
import requests
import pandas as pd

# %%
url = 'https://finance.naver.com/item/sise_day.nhn?code=005930'

# %%
header = {'user-agent': 
          'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36'}

# %%
r=requests.get(url, headers=header)

# %%
r.text
# Out:
# '\n<html lang="ko">\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=euc-kr">\n<title>네이버 금융</title>\n\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20210428175742/css/newstock.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20210428175742/css/common.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20210428175742/css/layout.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20210428175742/css/main.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20210428175742/css/newstock2.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20210428175742/css/newstock3.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20210428175742/css/world.css">\n</head>\n<body>\n<script language="JavaScript">\nfunction mouseOver(obj){\n  obj.style.backgroundColor="#f6f4e5";\n}\nfunction mouseOut(obj){\n  obj.style.backgroundColor="#ffffff";\n}\n</script>\n\t\t\t\t<h4 class="tlline2"><strong><span class="red03">일별</span>시세</strong></h4>\t\t\t\n\t\t\t\t<table cellspacing="0" class="type2">\n\t\t\t\t<tr>\n\t\t\t\t<th>날짜</th>\n\t\t\t\t<th>종가</th>\n\t\t\t\t<th>전일비</th>\n\t\t\t\t<th>시가</th>\n\t\t\t\t<th>고가</th>\n\t\t\t\t<th>저가</th>\n\t\t\t\t<th>거래량</th>\n\t\t\t\t</tr>\n\t\t\t\t<tr>\n\t\t\t\t<td colspan="7" height="8"></td>\n\t\t\t\t</tr>\n\n\n\t\n\t\t\t\t<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">\n\t\t\t\t<td align="center"><span class="tah p10 gray03">2021.05.03</span></td>\n\t\t\t\t<td class="num"><span class="tah p11">82,000</span></td>\n\t\t\t\t<td class="num">\n\t\t\t\t<img src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" width="7" height="6" style="margin-right:4px;" alt="상승"><span class="tah p11 red02">\n\t\t\t\t500\n\t\t\t\t</span>\n\t\t\t</td>\n\t\t\t\t<td class="num"><span class="tah p11">81,000</span></td>\n\t\t\t\t<td class="num"><span class="tah p11">82,400</span></td>\n\t\t\t\t<td class="num"><span class="tah p11">81,000</span></td>\n\t\t\t\t<td class="num"><span class="tah p11">8,780,070</span></td>\n\t\t\t\t</tr>\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">\n\t\t\t\t\t<td align="center"><span class="tah p10 gray03">2021.04.30</span></td>\n\t\t\t\t\t<td class="num"><span class="tah p11">81,500</span></td>\n\t\t\t\t\t<td class="num">\n\t\t\t\t<img src="https://ssl.pstatic.net/imgstock/images/images4/ico_down.gif" width="7" height="6" style="margin-right:4px;" alt="하락"><span class="tah p11 nv01">\n\t\t\t\t200\n\t\t\t\t</span>\n\t\t\t</td>\n\t\t\t\t\t<td class="num"><span class="tah p11">81,900</span></td>\n\t\t\t\t\t<td class="num"><span class="tah p11">82,100</span></td>\n\t\t\t\t\t<td class="num"><span class="tah p11">81,500</span></td>\n\t\t\t\t\t<td class="num"><span class="tah p11">18,673,197</span></td>\n\t\t\t\t\t</tr>\n\t\t\t\t\n\t\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t<tr onMouseOver="mouseOver(this)" onMouseOut="mouseOut(this)">\n\t\t\t\t\t<td align="center"><span class="tah p10 gray03">2021.04.29</span></td>\n\t\t\t\t\t<td class="num"><span class="tah p11">81,700</span></td>\n\t\t\t\t\t<td class="num">\n\t\t\t\t<img src="https://ssl.pstatic.net/imgstock/images/images4/ico_down.gif" width="7" height="6" style="margin-right:4px;" alt="하락"><span class="tah p11 nv01">\n\t\t\t\t400\n\t\t\t\t</span>\n\t\t\t</td>\n\t\t\t\t\t<td class="num"><span class="tah p11">82,400</span></td>\n\t\t\t\t\t<td class="num"><span class="tah p11">82,500</span></td>\n\t\t\t\t\t<td class="num"><span class="tah p11">81,500</span></td>\n\t\t\t\t\t<td class="num"><span class="tah p11">20,000,973</span></td>\n\t\t\t\t\t</tr>\n\t\t\t\t\n\t\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\n\t\t\n\t\t\t\n\t\t\ ...

# %%
pd.read_html(r.text)[0]
# Out:
#             날짜       종가     전일비       시가       고가       저가         거래량
# 0          NaN      NaN     NaN      NaN      NaN      NaN         NaN
# 1   2021.05.03  82000.0   500.0  81000.0  82400.0  81000.0   8780070.0
# 2   2021.04.30  81500.0   200.0  81900.0  82100.0  81500.0  18673197.0
# 3   2021.04.29  81700.0   400.0  82400.0  82500.0  81500.0  20000973.0
# 4   2021.04.28  82100.0   800.0  83200.0  83200.0  82100.0  15596759.0
# 5   2021.04.27  82900.0   600.0  83200.0  83300.0  82500.0  12941533.0
# 6          NaN      NaN     NaN      NaN      NaN      NaN         NaN
# 7          NaN      NaN     NaN      NaN      NaN      NaN         NaN
# 8          NaN      NaN     NaN      NaN      NaN      NaN         NaN
# 9   2021.04.26  83500.0   700.0  82900.0  83500.0  82600.0  15489938.0
# 10  2021.04.23  82800.0   400.0  81900.0  82900.0  81600.0  17805080.0
# 11  2021.04.22  82400.0   200.0  82900.0  83000.0  82400.0  13934746.0
# 12  2021.04.21  82600.0  1300.0  83300.0  83500.0  82500.0  21636079.0
# 13  2021.04.20  83900.0   600.0  83300.0  84000.0  83100.0  15521965.0
# 14         NaN      NaN     NaN      NaN      NaN      NaN         NaN

# %%
total=[]
for x in range(1,11):
    r = requests.get(url.format(x), headers=header)
    total.append(pd.read_html(r.text)[0].dropna())

# %%
stock = pd.concat(total)
stock
# Out:
#             날짜       종가     전일비       시가       고가       저가         거래량
# 1   2021.05.03  81800.0   300.0  81000.0  82400.0  81000.0  10710725.0
# 2   2021.04.30  81500.0   200.0  81900.0  82100.0  81500.0  18673197.0
# 3   2021.04.29  81700.0   400.0  82400.0  82500.0  81500.0  20000973.0
# 4   2021.04.28  82100.0   800.0  83200.0  83200.0  82100.0  15596759.0
# 5   2021.04.27  82900.0   600.0  83200.0  83300.0  82500.0  12941533.0
# ..         ...      ...     ...      ...      ...      ...         ...
# 9   2021.04.26  83500.0   700.0  82900.0  83500.0  82600.0  15489938.0
# 10  2021.04.23  82800.0   400.0  81900.0  82900.0  81600.0  17805080.0
# 11  2021.04.22  82400.0   200.0  82900.0  83000.0  82400.0  13934746.0
# 12  2021.04.21  82600.0  1300.0  83300.0  83500.0  82500.0  21636079.0
# 13  2021.04.20  83900.0   600.0  83300.0  84000.0  83100.0  15521965.0
#
# [100 rows x 7 columns]

# %%
stock.reset_index(drop=True, inplace=True)
stock
# Out:
#             날짜       종가     전일비       시가       고가       저가         거래량
# 0   2021.05.03  81800.0   300.0  81000.0  82400.0  81000.0  10710725.0
# 1   2021.04.30  81500.0   200.0  81900.0  82100.0  81500.0  18673197.0
# 2   2021.04.29  81700.0   400.0  82400.0  82500.0  81500.0  20000973.0
# 3   2021.04.28  82100.0   800.0  83200.0  83200.0  82100.0  15596759.0
# 4   2021.04.27  82900.0   600.0  83200.0  83300.0  82500.0  12941533.0
# ..         ...      ...     ...      ...      ...      ...         ...
# 95  2021.04.26  83500.0   700.0  82900.0  83500.0  82600.0  15489938.0
# 96  2021.04.23  82800.0   400.0  81900.0  82900.0  81600.0  17805080.0
# 97  2021.04.22  82400.0   200.0  82900.0  83000.0  82400.0  13934746.0
# 98  2021.04.21  82600.0  1300.0  83300.0  83500.0  82500.0  21636079.0
# 99  2021.04.20  83900.0   600.0  83300.0  84000.0  83100.0  15521965.0
#
# [100 rows x 7 columns]

# %% [markdown]
# ### 2번

# %%
post_url = 'https://api.finance.naver.com/siseJson.naver?'

# %%
header = {'user-agent': 
          'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36'}

# %%
payload = {'symbol': '005930',
            'requestType': '1',
            'startTime': '20171013',
            'endTime': '20180628',
            'timeframe': 'day'}

# %%
r = requests.post(post_url, data=payload, headers=header)

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '\n [[\'날짜\', \'시가\', \'고가\', \'저가\', \'종가\', \'거래량\', \'외국인소진율\'],\n\n\t\n\t\n\t\t\n["20171013", 54540, 54840, 53780, 54000, 252033, 53.36],\n\t\t\n["20171016", 53980, 54860, 53760, 53920, 195399, 53.36],\n\t\t\n["20171017", 54019, 55380, 54000, 54800, 212156, 53.39],\n\t\t\n["20171018", 54820, 55240, 54039, 54760, 202215, 53.39],\n\t\t\n["20171019", 54699, 54699, 52980, 52980, 242174, 53.38],\n\t\t\n["20171020", 52800, 54100, 52800, 53840, 160541, 53.41],\n\t\t\n["20171023", 54600, 54640, 54000, 54300, 166221, 53.44],\n\t\t\n["20171024", 54699, 54780, 54040, 54040, 116121, 53.43],\n\t\t\n["20171025", 54040, 54420, 53699, 53900, 117657, 53.44],\n\t\t\n["20171026", 53720, 53900, 52400, 52400, 195531, 53.44],\n\t\t\n["20171027", 52400, 53320, 52140, 53080, 147850, 53.42],\n\t\t\n["20171030", 53780, 54320, 53699, 54040, 163923, 53.44],\n\t\t\n["20171031", 54060, 55440, 53500, 55080, 267631, 53.48],\n\t\t\n["20171101", 57500, 57500, 56179, 57220, 290205, 53.5],\n\t\t\n["20171102", 57500, 57519, 56760, 57060, 214421, 53.77],\n\t\t\n["20171103", 57059, 57140, 55860, 56380, 198716, 53.71],\n\t\t\n["20171106", 56380, 56500, 55340, 56380, 180019, 53.72],\n\t\t\n["20171107", 56380, 56920, 55860, 56100, 149291, 53.71],\n\t\t\n["20171108", 56100, 57060, 55860, 56760, 170404, 53.71],\n\t\t\n["20171109", 56920, 56920, 55899, 56340, 239881, 53.69],\n\t\t\n["20171110", 55800, 56540, 55780, 56400, 134976, 53.67],\n\t\t\n["20171113", 56400, 56799, 56100, 56380, 176133, 53.68],\n\t\t\n["20171114", 56380, 56740, 55920, 55920, 134500, 53.64],\n\t\t\n["20171115", 55920, 56319, 55320, 55340, 176339, 53.61],\n\t\t\n["20171116", 55440, 56000, 55400, 55780, 152814, 53.62],\n\t\t\n["20171117", 56399, 56880, 55820, 55820, 214663, 53.66],\n\t\t\n["20171120", 55900, 55980, 55200, 55200, 189455, 53.65],\n\t\t\n["20171121", 55400, 55839, 55280, 55280, 206494, 53.63],\n\t\t\n["20171122", 55980, 56200, 55620, 55960, 159059, 53.6],\n\t\t\n["20171123", 55960, 55979, 55020, 55300, 125458, 53.57],\n\t\t\n["20171124", 55300, 55500, 55180, 55460, 90724, 53.54],\n\t\t\n["20171127", 55360, 55360, 52640, 52640, 362578, 53.45],\n\t\t\n["20171128", 52699, 53280, 51720, 53280, 269988, 53.43],\n\t\t\n["20171129", 53200, 53240, 52500, 52600, 191805, 53.37],\n\t\t\n["20171130", 50800, 51860, 50200, 50800, 592683, 53.25],\n\t\t\n["20171201", 50800, 51780, 50800, 50840, 257372, 53.21],\n\t\t\n["20171204", 50840, 51340, 50020, 51340, 297301, 53.19],\n\t\t\n["20171205", 50600, 51300, 50280, 51260, 186531, 53.17],\n\t\t\n["20171206", 51260, 51560, 50020, 50020, 217784, 53.11],\n\t\t\n["20171207", 50040, 50980, 50020, 50740, 221312, 53.05],\n\t\t\n["20171208", 51360, 52000, 51040, 52000, 225809, 53.07],\n\t\t\n["20171211", 52000, 52040, 51500, 51780, 162517, 53.01],\n\t\t\n["20171212", 51820, 52100, 51660, 52100, 175301, 53.02],\n\t\t\n["20171213", 52100, 52100, 51100, 51320, 226674, 52.95],\n\t\t\n["20171214", 51320, 52280, 51060, 51060, 406208, 52.99],\n\t\t\n["20171215", 51240, 51480, 50520, 50620, 298571, 52.95],\n\t\t\n["20171218", 50620, 51240, 50620, 51200, 147005, 52.91],\n\t\t\n["20171219", 51540, 52080, 51520, 51560, 239572, 52.9],\n\t\t\n["20171220", 51500, 51760, 50820, 50880, 201611, 52.84],\n\t\t\n["20171221", 51000, 51060, 49100, 49140, 312486, 52.78],\n\t\t\n["20171222", 49400, 49960, 49240, 49700, 223993, 52.79],\n\t\t\n["20171226", 49760, 50100, 48200, 48200, 320797, 52.75],\n\t\t\n["20171227", 48960, 49560, 48460, 49360, 214872, 52.74],\n\t\t\n["20171228", 49560, 50960, 49500, 50960, 179709, 52.74],\n\t\t\n["20180102", 51380, 51400, 50780, 51020, 169485, 52.75],\n\t\t\n["20180103", 52540, 52560, 51420, 51620, 200270, 52.81],\n\t\t\n["20180104", 52120, 52180, 50640, 51080, 233909, 52.82],\n\t\t\n["20180105", 51300, 52120, 51200, 52120, 189623, 52.83],\n\t\t\n["20180108", 52400, 52520, 51500, 52020, 167673, 52.84],\n\t\t\n["20180109", 51460, 51720, 49980, 50400, 360272, 52.77],\n\t\t\n["20180110", 50500, 50520, 48640, 48840, 371336, 52.69],\n\t\t\n["20180111", 48 ...

# %%
# 2021년 5월 3일 현재
# kospi 종목 4월 한달치 수집 -> 하나의 데이터 프레임
post_url = 'http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd'

# %%
payload = {'bld': 'dbms/MDC/STAT/standard/MDCSTAT01501',
           'mktId': 'STK',
           'trdDd': '20210401',
           'share': '1',
           'money': '1',
           'csvxls_isNo': 'false'}

# %%
r = requests.post(post_url, data=payload, headers=header)
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '{"OutBlock_1":[{"ISU_SRT_CD":"095570","ISU_ABBRV":"AJ네트웍스","MKT_NM":"KOSPI","SECT_TP_NM":"","TDD_CLSPRC":"4,620","FLUC_TP_CD":"1","CMPPREVDD_PRC":"115","FLUC_RT":"2.55","TDD_OPNPRC":"4,540","TDD_HGPRC":"4,625","TDD_LWPRC":"4,480","ACC_TRDVOL":"162,695","ACC_TRDVAL":"742,284,000","MKTCAP":"216,319,002,900","LIST_SHRS":"46,822,295","MKT_ID":"STK"},{"ISU_SRT_CD":"006840","ISU_ABBRV":"AK홀딩스","MKT_NM":"KOSPI","SECT_TP_NM":"","TDD_CLSPRC":"26,900","FLUC_TP_CD":"1","CMPPREVDD_PRC":"200","FLUC_RT":"0.75","TDD_OPNPRC":"26,800","TDD_HGPRC":"27,450","TDD_LWPRC":"26,750","ACC_TRDVOL":"34,663","ACC_TRDVAL":"936,083,050","MKTCAP":"356,359,390,900","LIST_SHRS":"13,247,561","MKT_ID":"STK"},{"ISU_SRT_CD":"027410","ISU_ABBRV":"BGF","MKT_NM":"KOSPI","SECT_TP_NM":"","TDD_CLSPRC":"7,270","FLUC_TP_CD":"1","CMPPREVDD_PRC":"260","FLUC_RT":"3.71","TDD_OPNPRC":"7,140","TDD_HGPRC":"7,500","TDD_LWPRC":"7,110","ACC_TRDVOL":"3,360,279","ACC_TRDVAL":"24,598,878,940","MKTCAP":"695,861,070,570","LIST_SHRS":"95,716,791","MKT_ID":"STK"},{"ISU_SRT_CD":"282330","ISU_ABBRV":"BGF리테일","MKT_NM":"KOSPI","SECT_TP_NM":"","TDD_CLSPRC":"162,500","FLUC_TP_CD":"1","CMPPREVDD_PRC":"4,500","FLUC_RT":"2.85","TDD_OPNPRC":"158,500","TDD_HGPRC":"162,500","TDD_LWPRC":"157,500","ACC_TRDVOL":"33,313","ACC_TRDVAL":"5,353,653,000","MKTCAP":"2,808,634,725,000","LIST_SHRS":"17,283,906","MKT_ID":"STK"},{"ISU_SRT_CD":"138930","ISU_ABBRV":"BNK금융지주","MKT_NM":"KOSPI","SECT_TP_NM":"","TDD_CLSPRC":"6,690","FLUC_TP_CD":"2","CMPPREVDD_PRC":"-100","FLUC_RT":"-1.47","TDD_OPNPRC":"6,810","TDD_HGPRC":"6,820","TDD_LWPRC":"6,670","ACC_TRDVOL":"1,346,763","ACC_TRDVAL":"9,041,413,000","MKTCAP":"2,180,506,795,740","LIST_SHRS":"325,935,246","MKT_ID":"STK"},{"ISU_SRT_CD":"001460","ISU_ABBRV":"BYC","MKT_NM":"KOSPI","SECT_TP_NM":"","TDD_CLSPRC":"345,000","FLUC_TP_CD":"2","CMPPREVDD_PRC":"-500","FLUC_RT":"-0.14","TDD_OPNPRC":"347,000","TDD_HGPRC":"347,500","TDD_LWPRC":"343,000","ACC_TRDVOL":"275","ACC_TRDVAL":"94,876,500","MKTCAP":"215,492,175,000","LIST_SHRS":"624,615","MKT_ID":"STK"},{"ISU_SRT_CD":"001465","ISU_ABBRV":"BYC우","MKT_NM":"KOSPI","SECT_TP_NM":"","TDD_CLSPRC":"151,000","FLUC_TP_CD":"2","CMPPREVDD_PRC":"-500","FLUC_RT":"-0.33","TDD_OPNPRC":"148,500","TDD_HGPRC":"152,000","TDD_LWPRC":"148,500","ACC_TRDVOL":"335","ACC_TRDVAL":"50,213,500","MKTCAP":"32,523,135,000","LIST_SHRS":"215,385","MKT_ID":"STK"},{"ISU_SRT_CD":"001040","ISU_ABBRV":"CJ","MKT_NM":"KOSPI","SECT_TP_NM":"","TDD_CLSPRC":"93,200","FLUC_TP_CD":"2","CMPPREVDD_PRC":"-800","FLUC_RT":"-0.85","TDD_OPNPRC":"94,200","TDD_HGPRC":"94,900","TDD_LWPRC":"93,000","ACC_TRDVOL":"47,470","ACC_TRDVAL":"4,444,290,400","MKTCAP":"2,719,296,213,600","LIST_SHRS":"29,176,998","MKT_ID":"STK"},{"ISU_SRT_CD":"079160","ISU_ABBRV":"CJ CGV","MKT_NM":"KOSPI","SECT_TP_NM":"","TDD_CLSPRC":"27,600","FLUC_TP_CD":"2","CMPPREVDD_PRC":"-450","FLUC_RT":"-1.60","TDD_OPNPRC":"28,050","TDD_HGPRC":"28,150","TDD_LWPRC":"27,500","ACC_TRDVOL":"218,506","ACC_TRDVAL":"6,057,274,650","MKTCAP":"968,760,000,000","LIST_SHRS":"35,100,000","MKT_ID":"STK"},{"ISU_SRT_CD":"00104K","ISU_ABBRV":"CJ4우(전환)","MKT_NM":"KOSPI","SECT_TP_NM":"","TDD_CLSPRC":"74,000","FLUC_TP_CD":"2","CMPPREVDD_PRC":"-700","FLUC_RT":"-0.94","TDD_OPNPRC":"74,700","TDD_HGPRC":"74,900","TDD_LWPRC":"73,800","ACC_TRDVOL":"2,469","ACC_TRDVAL":"183,344,700","MKTCAP":"312,761,888,000","LIST_SHRS":"4,226,512","MKT_ID":"STK"},{"ISU_SRT_CD":"000120","ISU_ABBRV":"CJ대한통운","MKT_NM":"KOSPI","SECT_TP_NM":"","TDD_CLSPRC":"180,500","FLUC_TP_CD":"2","CMPPREVDD_PRC":"-2,500","FLUC_RT":"-1.37","TDD_OPNPRC":"182,500","TDD_HGPRC":"185,500","TDD_LWPRC":"178,500","ACC_TRDVOL":"74,956","ACC_TRDVAL":"13,576,866,000","MKTCAP":"4,117,628,092,000","LIST_SHRS":"22,812,344","MKT_ID":"STK"},{"ISU_SRT_CD":"011150","ISU_ABBRV":"CJ씨푸드","MKT_NM":"KOSPI","SECT_TP_NM":"","TDD_CLSPRC":"4,705","FLUC_TP_CD":"2","CMPPREVDD_PRC":"-70","FLUC_RT":"-1.47","TDD_OPNPRC":"4,795","TDD_HGPRC":"4,800","TDD_LWPRC":"4,700","ACC_TRDVOL":"352,375","ACC_TRDVAL":"1,665,392, ...

# %%
import json

# %%
text = json.loads(r.text) # 텍스트를 딕셔너리 화 함.

# %%
r.json() # requests에서도 json화 시킬 수 있음.
# Out:
# {'OutBlock_1': [{'ISU_SRT_CD': '095570',
#    'ISU_ABBRV': 'AJ네트웍스',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '4,620',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '115',
#    'FLUC_RT': '2.55',
#    'TDD_OPNPRC': '4,540',
#    'TDD_HGPRC': '4,625',
#    'TDD_LWPRC': '4,480',
#    'ACC_TRDVOL': '162,695',
#    'ACC_TRDVAL': '742,284,000',
#    'MKTCAP': '216,319,002,900',
#    'LIST_SHRS': '46,822,295',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '006840',
#    'ISU_ABBRV': 'AK홀딩스',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '26,900',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '200',
#    'FLUC_RT': '0.75',
#    'TDD_OPNPRC': '26,800',
#    'TDD_HGPRC': '27,450',
#    'TDD_LWPRC': '26,750',
#    'ACC_TRDVOL': '34,663',
#    'ACC_TRDVAL': '936,083,050',
#    'MKTCAP': '356,359,390,900',
#    'LIST_SHRS': '13,247,561',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '027410',
#    'ISU_ABBRV': 'BGF',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '7,270',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '260',
#    'FLUC_RT': '3.71',
#    'TDD_OPNPRC': '7,140',
#    'TDD_HGPRC': '7,500',
#    'TDD_LWPRC': '7,110',
#    'ACC_TRDVOL': '3,360,279',
#    'ACC_TRDVAL': '24,598,878,940',
#    'MKTCAP': '695,861,070,570',
#    'LIST_SHRS': '95,716,791',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '282330',
#    'ISU_ABBRV': 'BGF리테일',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '162,500',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '4,500',
#    'FLUC_RT': '2.85',
#    'TDD_OPNPRC': '158,500',
#    'TDD_HGPRC': '162,500',
#    'TDD_LWPRC': '157,500',
#    'ACC_TRDVOL': '33,313',
#    'ACC_TRDVAL': '5,353,653,000',
#    'MKTCAP': '2,808,634,725,000',
#    'LIST_SHRS': '17,283,906',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '138930',
#    'ISU_ABBRV': 'BNK금융지주',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '6,690',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-100',
#    'FLUC_RT': '-1.47',
#    'TDD_OPNPRC': '6,810',
#    'TDD_HGPRC': '6,820',
#    'TDD_LWPRC': '6,670',
#    'ACC_TRDVOL': '1,346,763',
#    'ACC_TRDVAL': '9,041,413,000',
#    'MKTCAP': '2,180,506,795,740',
#    'LIST_SHRS': '325,935,246',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '001460',
#    'ISU_ABBRV': 'BYC',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '345,000',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-500',
#    'FLUC_RT': '-0.14',
#    'TDD_OPNPRC': '347,000',
#    'TDD_HGPRC': '347,500',
#    'TDD_LWPRC': '343,000',
#    'ACC_TRDVOL': '275',
#    'ACC_TRDVAL': '94,876,500',
#    'MKTCAP': '215,492,175,000',
#    'LIST_SHRS': '624,615',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '001465',
#    'ISU_ABBRV': 'BYC우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '151,000',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-500',
#    'FLUC_RT': '-0.33',
#    'TDD_OPNPRC': '148,500',
#    'TDD_HGPRC': '152,000',
#    'TDD_LWPRC': '148,500',
#    'ACC_TRDVOL': '335',
#    'ACC_TRDVAL': '50,213,500',
#    'MKTCAP': '32,523,135,000',
#    'LIST_SHRS': '215,385',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '001040',
#    'ISU_ABBRV': 'CJ',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '93,200',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-800',
#    'FLUC_RT': '-0.85',
#    'TDD_OPNPRC': '94,200',
#    'TDD_HGPRC': '94,900',
#    'TDD_LWPRC': '93,000',
#    'ACC_TRDVOL': '47,470',
#    'ACC_TRDVAL': '4,444,290,400',
#    'MKTCAP': '2,719,296,213,600',
#    'LIST_SHRS': '29,176,998',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '079160',
#    'ISU_ABBRV': 'CJ CGV',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '27,600',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-450',
#    'FLUC_RT': '-1.60',
#    'TDD_OPNPRC': '28,050',
#    'TDD_HGPRC': '28,150',
#    'TDD_LWPRC': '27,500',
#    'ACC_TRDVOL': '218,506',
#    'ACC_TRDVAL': '6,057,274,650',
#    'MKTCAP': '968,760,000,000',
#    'LIST_SHRS': '35,100,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '00104K',
#    'ISU_ABBRV': 'CJ4우(전환)',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '74,000',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-700',
#    'FLUC_RT': '-0.94',
#    'TDD_OPNPRC': '74,700',
#    'TDD_HGPRC': '74,900',
#    'TDD_LWPRC': '73,800',
#    'ACC_TRDVOL': '2,469',
#    'ACC_TRDVAL': '183,344,700',
#    'MKTCAP': '312,761,888,000',
#    'LIST_SHRS': '4,226,512',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '000120',
#    'ISU_ABBRV': 'CJ대한통운',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '180,500',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-2,500',
#    'FLUC_RT': '-1.37',
#    'TDD_OPNPRC': '182,500',
#    'TDD_HGPRC': '185,500',
#    'TDD_LWPRC': '178,500',
#    'ACC_TRDVOL': '74,956',
#    'ACC_TRDVAL': '13,576,866,000',
#    'MKTCAP': '4,117,628,092,000',
#    'LIST_SHRS': '22,812,344',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '011150',
#    'ISU_ABBRV': 'CJ씨푸드',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '4,705',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-70',
#    'FLUC_RT': '-1.47',
#    'TDD_OPNPRC': '4,795',
#    'TDD_HGPRC': '4,800',
#    'TDD_LWPRC': '4,700',
#    'ACC_TRDVOL': '352,375',
#    'ACC_TRDVAL': '1,665,392,935',
#    'MKTCAP': '169,054,286,965',
#    'LIST_SHRS': '35,930,773',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '011155',
#    'ISU_ABBRV': 'CJ씨푸드1우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '36,550',
#    'FLUC_TP_CD': '3',
#    'CMPPREVDD_PRC': '0',
#    'FLUC_RT': '0.00',
#    'TDD_OPNPRC': '36,850',
#    'TDD_HGPRC': '36,850',
#    'TDD_LWPRC': '36,550',
#    'ACC_TRDVOL': '363',
#    'ACC_TRDVAL': '13,367,750',
#    'MKTCAP': '7,310,000,000',
#    'LIST_SHRS': '200,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '001045',
#    'ISU_ABBRV': 'CJ우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '56,900',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '600',
#    'FLUC_RT': '1.07',
#    'TDD_OPNPRC': '56,300',
#    'TDD_HGPRC': '56,900',
#    'TDD_LWPRC': '55,800',
#    'ACC_TRDVOL': '1,229',
#    'ACC_TRDVAL': '69,380,800',
#    'MKTCAP': '128,606,688,700',
#    'LIST_SHRS': '2,260,223',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '097950',
#    'ISU_ABBRV': 'CJ제일제당',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '416,000',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '5,000',
#    'FLUC_RT': '1.22',
#    'TDD_OPNPRC': '413,000',
#    'TDD_HGPRC': '418,000',
#    'TDD_LWPRC': '412,500',
#    'ACC_TRDVOL': '38,393',
#    'ACC_TRDVAL': '15,937,646,000',
#    'MKTCAP': '6,262,541,376,000',
#    'LIST_SHRS': '15,054,186',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '097955',
#    'ISU_ABBRV': 'CJ제일제당 우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '187,000',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '3,000',
#    'FLUC_RT': '1.63',
#    'TDD_OPNPRC': '184,500',
#    'TDD_HGPRC': '187,000',
#    'TDD_LWPRC': '184,500',
#    'ACC_TRDVOL': '2,503',
#    'ACC_TRDVAL': '466,598,000',
#    'MKTCAP': '248,229,971,000',
#    'LIST_SHRS': '1,327,433',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '000590',
#    'ISU_ABBRV': 'CS홀딩스',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '63,400',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-900',
#    'FLUC_RT': '-1.40',
#    'TDD_OPNPRC': '64,300',
#    'TDD_HGPRC': '64,700',
#    'TDD_LWPRC': '62,400',
#    'ACC_TRDVOL': '4,564',
#    'ACC_TRDVAL': '289,199,600',
#    'MKTCAP': '73,194,158,800',
#    'LIST_SHRS': '1,154,482',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '012030',
#    'ISU_ABBRV': 'DB',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '877',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '6',
#    'FLUC_RT': '0.69',
#    'TDD_OPNPRC': '870',
#    'TDD_HGPRC': '878',
#    'TDD_LWPRC': '865',
#    'ACC_TRDVOL': '859,538',
#    'ACC_TRDVAL': '748,915,137',
#    'MKTCAP': '176,429,539,241',
#    'LIST_SHRS': '201,173,933',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '016610',
#    'ISU_ABBRV': 'DB금융투자',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '6,070',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '20',
#    'FLUC_RT': '0.33',
#    'TDD_OPNPRC': '6,080',
#    'TDD_HGPRC': '6,180',
#    'TDD_LWPRC': '6,040',
#    'ACC_TRDVOL': '259,614',
#    'ACC_TRDVAL': '1,585,031,160',
#    'MKTCAP': '257,649,581,230',
#    'LIST_SHRS': '42,446,389',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '005830',
#    'ISU_ABBRV': 'DB손해보험',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '47,200',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-100',
#    'FLUC_RT': '-0.21',
#    'TDD_OPNPRC': '47,300',
#    'TDD_HGPRC': '47,750',
#    'TDD_LWPRC': '46,450',
#    'ACC_TRDVOL': '151,950',
#    'ACC_TRDVAL': '7,145,236,650',
#    'MKTCAP': '3,341,760,000,000',
#    'LIST_SHRS': '70,800,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '000990',
#    'ISU_ABBRV': 'DB하이텍',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '57,700',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '1,400',
#    'FLUC_RT': '2.49',
#    'TDD_OPNPRC': '57,300',
#    'TDD_HGPRC': '58,000',
#    'TDD_LWPRC': '56,100',
#    'ACC_TRDVOL': '1,062,746',
#    'ACC_TRDVAL': '60,741,113,500',
#    'MKTCAP': '2,561,798,527,600',
#    'LIST_SHRS': '44,398,588',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '000995',
#    'ISU_ABBRV': 'DB하이텍1우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '103,500',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '500',
#    'FLUC_RT': '0.49',
#    'TDD_OPNPRC': '103,000',
#    'TDD_HGPRC': '104,500',
#    'TDD_LWPRC': '101,500',
#    'ACC_TRDVOL': '503',
#    'ACC_TRDVAL': '51,781,000',
#    'MKTCAP': '11,624,706,000',
#    'LIST_SHRS': '112,316',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '139130',
#    'ISU_ABBRV': 'DGB금융지주',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '8,350',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-90',
#    'FLUC_RT': '-1.07',
#    'TDD_OPNPRC': '8,450',
#    'TDD_HGPRC': '8,480',
#    'TDD_LWPRC': '8,240',
#    'ACC_TRDVOL': '654,019',
#    'ACC_TRDVAL': '5,456,035,450',
#    'MKTCAP': '1,412,367,705,550',
#    'LIST_SHRS': '169,145,833',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '001530',
#    'ISU_ABBRV': 'DI동일',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '173,500',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '2,000',
#    'FLUC_RT': '1.17',
#    'TDD_OPNPRC': '172,000',
#    'TDD_HGPRC': '177,000',
#    'TDD_LWPRC': '167,500',
#    'ACC_TRDVOL': '15,636',
#    'ACC_TRDVAL': '2,679,856,000',
#    'MKTCAP': '427,783,161,500',
#    'LIST_SHRS': '2,465,609',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '000210',
#    'ISU_ABBRV': 'DL',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '85,700',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-1,800',
#    'FLUC_RT': '-2.06',
#    'TDD_OPNPRC': '88,300',
#    'TDD_HGPRC': '88,300',
#    'TDD_LWPRC': '84,900',
#    'ACC_TRDVOL': '276,742',
#    'ACC_TRDVAL': '23,841,550,200',
#    'MKTCAP': '1,323,316,153,400',
#    'LIST_SHRS': '15,441,262',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '000215',
#    'ISU_ABBRV': 'DL우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '43,550',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-300',
#    'FLUC_RT': '-0.68',
#    'TDD_OPNPRC': '43,850',
#    'TDD_HGPRC': '44,000',
#    'TDD_LWPRC': '43,200',
#    'ACC_TRDVOL': '5,724',
#    'ACC_TRDVAL': '249,289,700',
#    'MKTCAP': '73,430,308,250',
#    'LIST_SHRS': '1,686,115',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '375500',
#    'ISU_ABBRV': 'DL이앤씨',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '119,500',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-1,000',
#    'FLUC_RT': '-0.83',
#    'TDD_OPNPRC': '121,000',
#    'TDD_HGPRC': '121,500',
#    'TDD_LWPRC': '118,500',
#    'ACC_TRDVOL': '252,464',
#    'ACC_TRDVAL': '30,184,141,500',
#    'MKTCAP': '2,313,369,191,000',
#    'LIST_SHRS': '19,358,738',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '37550K',
#    'ISU_ABBRV': 'DL이앤씨우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '73,400',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-200',
#    'FLUC_RT': '-0.27',
#    'TDD_OPNPRC': '73,200',
#    'TDD_HGPRC': '74,000',
#    'TDD_LWPRC': '72,900',
#    'ACC_TRDVOL': '8,633',
#    'ACC_TRDVAL': '633,362,800',
#    'MKTCAP': '155,159,159,000',
#    'LIST_SHRS': '2,113,885',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '004840',
#    'ISU_ABBRV': 'DRB동일',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '6,760',
#    'FLUC_TP_CD': '3',
#    'CMPPREVDD_PRC': '0',
#    'FLUC_RT': '0.00',
#    'TDD_OPNPRC': '6,770',
#    'TDD_HGPRC': '6,960',
#    'TDD_LWPRC': '6,690',
#    'ACC_TRDVOL': '30,198',
#    'ACC_TRDVAL': '203,782,660',
#    'MKTCAP': '134,726,800,000',
#    'LIST_SHRS': '19,930,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '155660',
#    'ISU_ABBRV': 'DSR',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '5,690',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '10',
#    'FLUC_RT': '0.18',
#    'TDD_OPNPRC': '5,690',
#    'TDD_HGPRC': '5,710',
#    'TDD_LWPRC': '5,610',
#    'ACC_TRDVOL': '83,939',
#    'ACC_TRDVAL': '475,788,750',
#    'MKTCAP': '91,040,000,000',
#    'LIST_SHRS': '16,000,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '069730',
#    'ISU_ABBRV': 'DSR제강',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '5,530',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '20',
#    'FLUC_RT': '0.36',
#    'TDD_OPNPRC': '5,510',
#    'TDD_HGPRC': '5,530',
#    'TDD_LWPRC': '5,430',
#    'ACC_TRDVOL': '132,175',
#    'ACC_TRDVAL': '725,139,020',
#    'MKTCAP': '79,632,000,000',
#    'LIST_SHRS': '14,400,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '017940',
#    'ISU_ABBRV': 'E1',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '43,100',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '200',
#    'FLUC_RT': '0.47',
#    'TDD_OPNPRC': '43,000',
#    'TDD_HGPRC': '43,250',
#    'TDD_LWPRC': '42,850',
#    'ACC_TRDVOL': '13,326',
#    'ACC_TRDVAL': '573,938,750',
#    'MKTCAP': '295,666,000,000',
#    'LIST_SHRS': '6,860,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '365550',
#    'ISU_ABBRV': 'ESR켄달스퀘어리츠',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '6,060',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '30',
#    'FLUC_RT': '0.50',
#    'TDD_OPNPRC': '6,030',
#    'TDD_HGPRC': '6,100',
#    'TDD_LWPRC': '6,020',
#    'ACC_TRDVOL': '189,351',
#    'ACC_TRDVAL': '1,148,250,050',
#    'MKTCAP': '868,149,540,000',
#    'LIST_SHRS': '143,259,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '007700',
#    'ISU_ABBRV': 'F&F',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '138,500',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '11,000',
#    'FLUC_RT': '8.63',
#    'TDD_OPNPRC': '126,500',
#    'TDD_HGPRC': '143,500',
#    'TDD_LWPRC': '126,500',
#    'ACC_TRDVOL': '248,476',
#    'ACC_TRDVAL': '33,863,974,500',
#    'MKTCAP': '2,132,900,000,000',
#    'LIST_SHRS': '15,400,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '114090',
#    'ISU_ABBRV': 'GKL',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '16,550',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-100',
#    'FLUC_RT': '-0.60',
#    'TDD_OPNPRC': '16,650',
#    'TDD_HGPRC': '16,800',
#    'TDD_LWPRC': '16,400',
#    'ACC_TRDVOL': '181,540',
#    'ACC_TRDVAL': '3,011,682,550',
#    'MKTCAP': '1,023,711,338,500',
#    'LIST_SHRS': '61,855,670',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '078930',
#    'ISU_ABBRV': 'GS',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '39,200',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '100',
#    'FLUC_RT': '0.26',
#    'TDD_OPNPRC': '39,100',
#    'TDD_HGPRC': '39,350',
#    'TDD_LWPRC': '38,950',
#    'ACC_TRDVOL': '216,954',
#    'ACC_TRDVAL': '8,488,322,100',
#    'MKTCAP': '3,642,282,817,600',
#    'LIST_SHRS': '92,915,378',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '006360',
#    'ISU_ABBRV': 'GS건설',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '41,700',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-1,300',
#    'FLUC_RT': '-3.02',
#    'TDD_OPNPRC': '43,400',
#    'TDD_HGPRC': '43,400',
#    'TDD_LWPRC': '41,500',
#    'ACC_TRDVOL': '1,600,795',
#    'ACC_TRDVAL': '67,068,485,750',
#    'MKTCAP': '3,564,969,195,600',
#    'LIST_SHRS': '85,490,868',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '001250',
#    'ISU_ABBRV': 'GS글로벌',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '2,450',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-50',
#    'FLUC_RT': '-2.00',
#    'TDD_OPNPRC': '2,500',
#    'TDD_HGPRC': '2,510',
#    'TDD_LWPRC': '2,435',
#    'ACC_TRDVOL': '771,932',
#    'ACC_TRDVAL': '1,902,349,235',
#    'MKTCAP': '202,207,721,800',
#    'LIST_SHRS': '82,533,764',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '007070',
#    'ISU_ABBRV': 'GS리테일',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '38,250',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '100',
#    'FLUC_RT': '0.26',
#    'TDD_OPNPRC': '38,250',
#    'TDD_HGPRC': '38,500',
#    'TDD_LWPRC': '38,200',
#    'ACC_TRDVOL': '180,488',
#    'ACC_TRDVAL': '6,923,531,950',
#    'MKTCAP': '2,945,250,000,000',
#    'LIST_SHRS': '77,000,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '078935',
#    'ISU_ABBRV': 'GS우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '32,600',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '300',
#    'FLUC_RT': '0.93',
#    'TDD_OPNPRC': '32,300',
#    'TDD_HGPRC': '32,800',
#    'TDD_LWPRC': '32,300',
#    'ACC_TRDVOL': '10,146',
#    'ACC_TRDVAL': '330,925,150',
#    'MKTCAP': '58,185,327,600',
#    'LIST_SHRS': '1,784,826',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '012630',
#    'ISU_ABBRV': 'HDC',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '11,350',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '100',
#    'FLUC_RT': '0.89',
#    'TDD_OPNPRC': '11,250',
#    'TDD_HGPRC': '11,350',
#    'TDD_LWPRC': '11,200',
#    'ACC_TRDVOL': '348,692',
#    'ACC_TRDVAL': '3,935,993,750',
#    'MKTCAP': '678,068,533,350',
#    'LIST_SHRS': '59,741,721',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '039570',
#    'ISU_ABBRV': 'HDC아이콘트롤스',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '10,100',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-50',
#    'FLUC_RT': '-0.49',
#    'TDD_OPNPRC': '10,250',
#    'TDD_HGPRC': '10,300',
#    'TDD_LWPRC': '10,000',
#    'ACC_TRDVOL': '42,256',
#    'ACC_TRDVAL': '426,795,200',
#    'MKTCAP': '166,246,000,000',
#    'LIST_SHRS': '16,460,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '089470',
#    'ISU_ABBRV': 'HDC현대EP',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '6,200',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-90',
#    'FLUC_RT': '-1.43',
#    'TDD_OPNPRC': '6,300',
#    'TDD_HGPRC': '6,330',
#    'TDD_LWPRC': '6,160',
#    'ACC_TRDVOL': '206,329',
#    'ACC_TRDVAL': '1,281,412,410',
#    'MKTCAP': '197,780,000,000',
#    'LIST_SHRS': '31,900,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '294870',
#    'ISU_ABBRV': 'HDC현대산업개발',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '28,900',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-450',
#    'FLUC_RT': '-1.53',
#    'TDD_OPNPRC': '29,350',
#    'TDD_HGPRC': '29,400',
#    'TDD_LWPRC': '28,700',
#    'ACC_TRDVOL': '456,767',
#    'ACC_TRDVAL': '13,222,561,950',
#    'MKTCAP': '1,904,721,837,000',
#    'LIST_SHRS': '65,907,330',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '011200',
#    'ISU_ABBRV': 'HMM',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '27,800',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-1,200',
#    'FLUC_RT': '-4.14',
#    'TDD_OPNPRC': '28,400',
#    'TDD_HGPRC': '28,500',
#    'TDD_LWPRC': '26,550',
#    'ACC_TRDVOL': '18,982,890',
#    'ACC_TRDVAL': '522,857,328,850',
#    'MKTCAP': '9,470,019,876,600',
#    'LIST_SHRS': '340,648,197',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '082740',
#    'ISU_ABBRV': 'HSD엔진',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '9,390',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '30',
#    'FLUC_RT': '0.32',
#    'TDD_OPNPRC': '9,400',
#    'TDD_HGPRC': '9,450',
#    'TDD_LWPRC': '9,000',
#    'ACC_TRDVOL': '1,450,579',
#    'ACC_TRDVAL': '13,381,070,100',
#    'MKTCAP': '381,228,572,580',
#    'LIST_SHRS': '40,599,422',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '003560',
#    'ISU_ABBRV': 'IHQ',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '2,005',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '10',
#    'FLUC_RT': '0.50',
#    'TDD_OPNPRC': '2,000',
#    'TDD_HGPRC': '2,015',
#    'TDD_LWPRC': '1,835',
#    'ACC_TRDVOL': '2,170,148',
#    'ACC_TRDVAL': '4,231,908,660',
#    'MKTCAP': '293,202,674,740',
#    'LIST_SHRS': '146,235,748',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '175330',
#    'ISU_ABBRV': 'JB금융지주',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '6,540',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-10',
#    'FLUC_RT': '-0.15',
#    'TDD_OPNPRC': '6,550',
#    'TDD_HGPRC': '6,550',
#    'TDD_LWPRC': '6,440',
#    'ACC_TRDVOL': '479,849',
#    'ACC_TRDVAL': '3,112,354,650',
#    'MKTCAP': '1,288,268,126,760',
#    'LIST_SHRS': '196,982,894',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '234080',
#    'ISU_ABBRV': 'JW생명과학',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '18,950',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-50',
#    'FLUC_RT': '-0.26',
#    'TDD_OPNPRC': '19,100',
#    'TDD_HGPRC': '19,250',
#    'TDD_LWPRC': '18,900',
#    'ACC_TRDVOL': '187,921',
#    'ACC_TRDVAL': '3,580,834,200',
#    'MKTCAP': '300,064,798,300',
#    'LIST_SHRS': '15,834,554',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '001060',
#    'ISU_ABBRV': 'JW중외제약',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '29,950',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '300',
#    'FLUC_RT': '1.01',
#    'TDD_OPNPRC': '29,450',
#    'TDD_HGPRC': '30,150',
#    'TDD_LWPRC': '29,450',
#    'ACC_TRDVOL': '53,256',
#    'ACC_TRDVAL': '1,593,325,100',
#    'MKTCAP': '645,120,783,700',
#    'LIST_SHRS': '21,539,926',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '001067',
#    'ISU_ABBRV': 'JW중외제약2우B',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '64,900',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '400',
#    'FLUC_RT': '0.62',
#    'TDD_OPNPRC': '65,000',
#    'TDD_HGPRC': '65,000',
#    'TDD_LWPRC': '64,100',
#    'ACC_TRDVOL': '371',
#    'ACC_TRDVAL': '24,010,600',
#    'MKTCAP': '6,037,517,200',
#    'LIST_SHRS': '93,028',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '001065',
#    'ISU_ABBRV': 'JW중외제약우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '33,000',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-300',
#    'FLUC_RT': '-0.90',
#    'TDD_OPNPRC': '33,900',
#    'TDD_HGPRC': '33,900',
#    'TDD_LWPRC': '33,000',
#    'ACC_TRDVOL': '1,443',
#    'ACC_TRDVAL': '47,958,050',
#    'MKTCAP': '5,857,038,000',
#    'LIST_SHRS': '177,486',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '096760',
#    'ISU_ABBRV': 'JW홀딩스',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '4,610',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '55',
#    'FLUC_RT': '1.21',
#    'TDD_OPNPRC': '4,575',
#    'TDD_HGPRC': '4,640',
#    'TDD_LWPRC': '4,555',
#    'ACC_TRDVOL': '249,561',
#    'ACC_TRDVAL': '1,149,840,810',
#    'MKTCAP': '315,513,849,020',
#    'LIST_SHRS': '68,441,182',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '105560',
#    'ISU_ABBRV': 'KB금융',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '55,000',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-1,200',
#    'FLUC_RT': '-2.14',
#    'TDD_OPNPRC': '55,300',
#    'TDD_HGPRC': '56,000',
#    'TDD_LWPRC': '54,600',
#    'ACC_TRDVOL': '1,495,543',
#    'ACC_TRDVAL': '82,324,336,700',
#    'MKTCAP': '22,869,435,600,000',
#    'LIST_SHRS': '415,807,920',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '002380',
#    'ISU_ABBRV': 'KCC',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '235,000',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-2,500',
#    'FLUC_RT': '-1.05',
#    'TDD_OPNPRC': '237,000',
#    'TDD_HGPRC': '240,000',
#    'TDD_LWPRC': '232,500',
#    'ACC_TRDVOL': '49,100',
#    'ACC_TRDVAL': '11,603,687,500',
#    'MKTCAP': '2,088,320,685,000',
#    'LIST_SHRS': '8,886,471',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '009070',
#    'ISU_ABBRV': 'KCTC',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '6,500',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '70',
#    'FLUC_RT': '1.09',
#    'TDD_OPNPRC': '6,500',
#    'TDD_HGPRC': '6,660',
#    'TDD_LWPRC': '6,430',
#    'ACC_TRDVOL': '998,815',
#    'ACC_TRDVAL': '6,517,745,880',
#    'MKTCAP': '195,000,000,000',
#    'LIST_SHRS': '30,000,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '009440',
#    'ISU_ABBRV': 'KC그린홀딩스',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '4,695',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-15',
#    'FLUC_RT': '-0.32',
#    'TDD_OPNPRC': '4,720',
#    'TDD_HGPRC': '4,755',
#    'TDD_LWPRC': '4,630',
#    'ACC_TRDVOL': '77,841',
#    'ACC_TRDVAL': '363,369,080',
#    'MKTCAP': '105,332,231,100',
#    'LIST_SHRS': '22,434,980',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '119650',
#    'ISU_ABBRV': 'KC코트렐',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '9,380',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-270',
#    'FLUC_RT': '-2.80',
#    'TDD_OPNPRC': '9,700',
#    'TDD_HGPRC': '9,700',
#    'TDD_LWPRC': '9,380',
#    'ACC_TRDVOL': '289,932',
#    'ACC_TRDVAL': '2,745,172,760',
#    'MKTCAP': '121,940,000,000',
#    'LIST_SHRS': '13,000,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '092220',
#    'ISU_ABBRV': 'KEC',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '2,360',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '35',
#    'FLUC_RT': '1.51',
#    'TDD_OPNPRC': '2,350',
#    'TDD_HGPRC': '2,460',
#    'TDD_LWPRC': '2,330',
#    'ACC_TRDVOL': '5,015,534',
#    'ACC_TRDVAL': '11,988,651,500',
#    'MKTCAP': '275,428,378,400',
#    'LIST_SHRS': '116,706,940',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '016380',
#    'ISU_ABBRV': 'KG동부제철',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '14,550',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-750',
#    'FLUC_RT': '-4.90',
#    'TDD_OPNPRC': '15,600',
#    'TDD_HGPRC': '15,650',
#    'TDD_LWPRC': '14,350',
#    'ACC_TRDVOL': '1,040,368',
#    'ACC_TRDVAL': '15,368,723,100',
#    'MKTCAP': '1,455,129,451,350',
#    'LIST_SHRS': '100,008,897',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '016385',
#    'ISU_ABBRV': 'KG동부제철우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '120,500',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-1,000',
#    'FLUC_RT': '-0.82',
#    'TDD_OPNPRC': '118,000',
#    'TDD_HGPRC': '121,500',
#    'TDD_LWPRC': '118,000',
#    'ACC_TRDVOL': '114',
#    'ACC_TRDVAL': '13,646,500',
#    'MKTCAP': '6,432,892,500',
#    'LIST_SHRS': '53,385',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '001390',
#    'ISU_ABBRV': 'KG케미칼',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '26,650',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-350',
#    'FLUC_RT': '-1.30',
#    'TDD_OPNPRC': '27,300',
#    'TDD_HGPRC': '27,550',
#    'TDD_LWPRC': '26,500',
#    'ACC_TRDVOL': '141,183',
#    'ACC_TRDVAL': '3,784,978,750',
#    'MKTCAP': '369,531,458,400',
#    'LIST_SHRS': '13,866,096',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '001940',
#    'ISU_ABBRV': 'KISCO홀딩스',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '17,100',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-200',
#    'FLUC_RT': '-1.16',
#    'TDD_OPNPRC': '17,200',
#    'TDD_HGPRC': '17,300',
#    'TDD_LWPRC': '16,700',
#    'ACC_TRDVOL': '49,995',
#    'ACC_TRDVAL': '852,972,750',
#    'MKTCAP': '315,946,098,000',
#    'LIST_SHRS': '18,476,380',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '025000',
#    'ISU_ABBRV': 'KPX케미칼',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '63,600',
#    'FLUC_TP_CD': '3',
#    'CMPPREVDD_PRC': '0',
#    'FLUC_RT': '0.00',
#    'TDD_OPNPRC': '63,800',
#    'TDD_HGPRC': '64,100',
#    'TDD_LWPRC': '63,500',
#    'ACC_TRDVOL': '5,029',
#    'ACC_TRDVAL': '320,068,900',
#    'MKTCAP': '307,824,000,000',
#    'LIST_SHRS': '4,840,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '092230',
#    'ISU_ABBRV': 'KPX홀딩스',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '61,500',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '1,300',
#    'FLUC_RT': '2.16',
#    'TDD_OPNPRC': '60,400',
#    'TDD_HGPRC': '61,500',
#    'TDD_LWPRC': '59,000',
#    'ACC_TRDVOL': '15,818',
#    'ACC_TRDVAL': '957,934,800',
#    'MKTCAP': '259,815,729,000',
#    'LIST_SHRS': '4,224,646',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '000040',
#    'ISU_ABBRV': 'KR모터스',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '1,300',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-15',
#    'FLUC_RT': '-1.14',
#    'TDD_OPNPRC': '1,340',
#    'TDD_HGPRC': '1,340',
#    'TDD_LWPRC': '1,295',
#    'ACC_TRDVOL': '1,065,657',
#    'ACC_TRDVAL': '1,392,668,920',
#    'MKTCAP': '124,978,578,400',
#    'LIST_SHRS': '96,137,368',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '044450',
#    'ISU_ABBRV': 'KSS해운',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '11,000',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '50',
#    'FLUC_RT': '0.46',
#    'TDD_OPNPRC': '10,950',
#    'TDD_HGPRC': '11,050',
#    'TDD_LWPRC': '10,800',
#    'ACC_TRDVOL': '104,266',
#    'ACC_TRDVAL': '1,139,045,350',
#    'MKTCAP': '255,044,680,000',
#    'LIST_SHRS': '23,185,880',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '030200',
#    'ISU_ABBRV': 'KT',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '28,200',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-50',
#    'FLUC_RT': '-0.18',
#    'TDD_OPNPRC': '28,400',
#    'TDD_HGPRC': '28,750',
#    'TDD_LWPRC': '28,100',
#    'ACC_TRDVOL': '1,102,601',
#    'ACC_TRDVAL': '31,264,173,850',
#    'MKTCAP': '7,363,352,985,600',
#    'LIST_SHRS': '261,111,808',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '033780',
#    'ISU_ABBRV': 'KT&G',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '81,400',
#    'FLUC_TP_CD': '3',
#    'CMPPREVDD_PRC': '0',
#    'FLUC_RT': '0.00',
#    'TDD_OPNPRC': '81,400',
#    'TDD_HGPRC': '81,800',
#    'TDD_LWPRC': '81,300',
#    'ACC_TRDVOL': '292,379',
#    'ACC_TRDVAL': '23,832,762,800',
#    'MKTCAP': '11,175,609,255,800',
#    'LIST_SHRS': '137,292,497',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '030210',
#    'ISU_ABBRV': 'KTB투자증권',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '4,820',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '5',
#    'FLUC_RT': '0.10',
#    'TDD_OPNPRC': '4,860',
#    'TDD_HGPRC': '4,915',
#    'TDD_LWPRC': '4,795',
#    'ACC_TRDVOL': '655,814',
#    'ACC_TRDVAL': '3,176,214,145',
#    'MKTCAP': '290,713,923,440',
#    'LIST_SHRS': '60,314,092',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '058850',
#    'ISU_ABBRV': 'KTcs',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '2,975',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '50',
#    'FLUC_RT': '1.71',
#    'TDD_OPNPRC': '2,935',
#    'TDD_HGPRC': '3,030',
#    'TDD_LWPRC': '2,930',
#    'ACC_TRDVOL': '1,192,290',
#    'ACC_TRDVAL': '3,554,669,590',
#    'MKTCAP': '126,987,875,000',
#    'LIST_SHRS': '42,685,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '058860',
#    'ISU_ABBRV': 'KTis',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '2,970',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-45',
#    'FLUC_RT': '-1.49',
#    'TDD_OPNPRC': '3,015',
#    'TDD_HGPRC': '3,030',
#    'TDD_LWPRC': '2,970',
#    'ACC_TRDVOL': '193,767',
#    'ACC_TRDVAL': '580,962,825',
#    'MKTCAP': '103,361,940,000',
#    'LIST_SHRS': '34,802,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '093050',
#    'ISU_ABBRV': 'LF',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '16,700',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '350',
#    'FLUC_RT': '2.14',
#    'TDD_OPNPRC': '16,500',
#    'TDD_HGPRC': '16,750',
#    'TDD_LWPRC': '16,400',
#    'ACC_TRDVOL': '219,809',
#    'ACC_TRDVAL': '3,661,581,000',
#    'MKTCAP': '488,308,000,000',
#    'LIST_SHRS': '29,240,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '003550',
#    'ISU_ABBRV': 'LG',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '91,300',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '900',
#    'FLUC_RT': '1.00',
#    'TDD_OPNPRC': '90,800',
#    'TDD_HGPRC': '91,400',
#    'TDD_LWPRC': '89,500',
#    'ACC_TRDVOL': '339,537',
#    'ACC_TRDVAL': '30,780,823,400',
#    'MKTCAP': '15,754,466,060,300',
#    'LIST_SHRS': '172,557,131',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '034220',
#    'ISU_ABBRV': 'LG디스플레이',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '22,500',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-250',
#    'FLUC_RT': '-1.10',
#    'TDD_OPNPRC': '22,900',
#    'TDD_HGPRC': '22,950',
#    'TDD_LWPRC': '22,400',
#    'ACC_TRDVOL': '2,078,109',
#    'ACC_TRDVAL': '46,920,233,800',
#    'MKTCAP': '8,050,853,250,000',
#    'LIST_SHRS': '357,815,700',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '001120',
#    'ISU_ABBRV': 'LG상사',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '31,100',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-800',
#    'FLUC_RT': '-2.51',
#    'TDD_OPNPRC': '31,700',
#    'TDD_HGPRC': '32,150',
#    'TDD_LWPRC': '30,700',
#    'ACC_TRDVOL': '302,707',
#    'ACC_TRDVAL': '9,508,563,150',
#    'MKTCAP': '1,205,436,000,000',
#    'LIST_SHRS': '38,760,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '051900',
#    'ISU_ABBRV': 'LG생활건강',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '1,578,000',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '8,000',
#    'FLUC_RT': '0.51',
#    'TDD_OPNPRC': '1,570,000',
#    'TDD_HGPRC': '1,588,000',
#    'TDD_LWPRC': '1,562,000',
#    'ACC_TRDVOL': '19,512',
#    'ACC_TRDVAL': '30,737,128,000',
#    'MKTCAP': '24,645,514,866,000',
#    'LIST_SHRS': '15,618,197',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '051905',
#    'ISU_ABBRV': 'LG생활건강우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '692,000',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '7,000',
#    'FLUC_RT': '1.02',
#    'TDD_OPNPRC': '689,000',
#    'TDD_HGPRC': '692,000',
#    'TDD_LWPRC': '686,000',
#    'ACC_TRDVOL': '2,102',
#    'ACC_TRDVAL': '1,448,343,500',
#    'MKTCAP': '1,452,990,324,000',
#    'LIST_SHRS': '2,099,697',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '003555',
#    'ISU_ABBRV': 'LG우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '72,400',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '200',
#    'FLUC_RT': '0.28',
#    'TDD_OPNPRC': '72,800',
#    'TDD_HGPRC': '73,200',
#    'TDD_LWPRC': '72,100',
#    'ACC_TRDVOL': '18,291',
#    'ACC_TRDVAL': '1,327,784,600',
#    'MKTCAP': '239,982,614,800',
#    'LIST_SHRS': '3,314,677',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '032640',
#    'ISU_ABBRV': 'LG유플러스',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '12,250',
#    'FLUC_TP_CD': '3',
#    'CMPPREVDD_PRC': '0',
#    'FLUC_RT': '0.00',
#    'TDD_OPNPRC': '12,300',
#    'TDD_HGPRC': '12,350',
#    'TDD_LWPRC': '12,200',
#    'ACC_TRDVOL': '1,201,566',
#    'ACC_TRDVAL': '14,755,286,500',
#    'MKTCAP': '5,348,489,172,250',
#    'LIST_SHRS': '436,611,361',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '011070',
#    'ISU_ABBRV': 'LG이노텍',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '209,000',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '3,500',
#    'FLUC_RT': '1.70',
#    'TDD_OPNPRC': '210,500',
#    'TDD_HGPRC': '210,500',
#    'TDD_LWPRC': '206,500',
#    'ACC_TRDVOL': '132,923',
#    'ACC_TRDVAL': '27,737,640,000',
#    'MKTCAP': '4,946,425,363,000',
#    'LIST_SHRS': '23,667,107',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '066570',
#    'ISU_ABBRV': 'LG전자',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '159,000',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '9,000',
#    'FLUC_RT': '6.00',
#    'TDD_OPNPRC': '154,500',
#    'TDD_HGPRC': '160,500',
#    'TDD_LWPRC': '150,500',
#    'ACC_TRDVOL': '3,574,578',
#    'ACC_TRDVAL': '560,805,115,500',
#    'MKTCAP': '26,020,002,426,000',
#    'LIST_SHRS': '163,647,814',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '066575',
#    'ISU_ABBRV': 'LG전자우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '73,900',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '3,400',
#    'FLUC_RT': '4.82',
#    'TDD_OPNPRC': '71,800',
#    'TDD_HGPRC': '75,400',
#    'TDD_LWPRC': '70,700',
#    'ACC_TRDVOL': '432,366',
#    'ACC_TRDVAL': '31,653,570,900',
#    'MKTCAP': '1,270,044,808,800',
#    'LIST_SHRS': '17,185,992',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '108670',
#    'ISU_ABBRV': 'LG하우시스',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '79,000',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-6,000',
#    'FLUC_RT': '-7.06',
#    'TDD_OPNPRC': '80,900',
#    'TDD_HGPRC': '82,500',
#    'TDD_LWPRC': '77,900',
#    'ACC_TRDVOL': '604,627',
#    'ACC_TRDVAL': '48,131,224,200',
#    'MKTCAP': '708,445,930,000',
#    'LIST_SHRS': '8,967,670',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '108675',
#    'ISU_ABBRV': 'LG하우시스우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '36,600',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-2,200',
#    'FLUC_RT': '-5.67',
#    'TDD_OPNPRC': '36,800',
#    'TDD_HGPRC': '38,250',
#    'TDD_LWPRC': '36,050',
#    'ACC_TRDVOL': '34,742',
#    'ACC_TRDVAL': '1,276,918,150',
#    'MKTCAP': '37,783,278,000',
#    'LIST_SHRS': '1,032,330',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '037560',
#    'ISU_ABBRV': 'LG헬로비전',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '4,780',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-140',
#    'FLUC_RT': '-2.85',
#    'TDD_OPNPRC': '4,890',
#    'TDD_HGPRC': '4,920',
#    'TDD_LWPRC': '4,740',
#    'ACC_TRDVOL': '1,114,565',
#    'ACC_TRDVAL': '5,350,546,195',
#    'MKTCAP': '370,196,014,700',
#    'LIST_SHRS': '77,446,865',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '051910',
#    'ISU_ABBRV': 'LG화학',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '819,000',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '14,000',
#    'FLUC_RT': '1.74',
#    'TDD_OPNPRC': '817,000',
#    'TDD_HGPRC': '822,000',
#    'TDD_LWPRC': '811,000',
#    'ACC_TRDVOL': '361,295',
#    'ACC_TRDVAL': '295,111,839,000',
#    'MKTCAP': '57,815,128,917,000',
#    'LIST_SHRS': '70,592,343',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '051915',
#    'ISU_ABBRV': 'LG화학우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '389,500',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '5,500',
#    'FLUC_RT': '1.43',
#    'TDD_OPNPRC': '386,000',
#    'TDD_HGPRC': '390,000',
#    'TDD_LWPRC': '385,000',
#    'ACC_TRDVOL': '18,925',
#    'ACC_TRDVAL': '7,344,534,500',
#    'MKTCAP': '2,994,787,600,000',
#    'LIST_SHRS': '7,688,800',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '079550',
#    'ISU_ABBRV': 'LIG넥스원',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '40,450',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '300',
#    'FLUC_RT': '0.75',
#    'TDD_OPNPRC': '40,350',
#    'TDD_HGPRC': '40,600',
#    'TDD_LWPRC': '39,600',
#    'ACC_TRDVOL': '142,695',
#    'ACC_TRDVAL': '5,742,394,000',
#    'MKTCAP': '889,900,000,000',
#    'LIST_SHRS': '22,000,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '006260',
#    'ISU_ABBRV': 'LS',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '67,700',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-800',
#    'FLUC_RT': '-1.17',
#    'TDD_OPNPRC': '69,800',
#    'TDD_HGPRC': '69,800',
#    'TDD_LWPRC': '67,500',
#    'ACC_TRDVOL': '189,341',
#    'ACC_TRDVAL': '12,957,688,600',
#    'MKTCAP': '2,179,940,000,000',
#    'LIST_SHRS': '32,200,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '010120',
#    'ISU_ABBRV': 'LS ELECTRIC',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '61,200',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '300',
#    'FLUC_RT': '0.49',
#    'TDD_OPNPRC': '61,100',
#    'TDD_HGPRC': '61,500',
#    'TDD_LWPRC': '60,600',
#    'ACC_TRDVOL': '72,388',
#    'ACC_TRDVAL': '4,415,620,700',
#    'MKTCAP': '1,836,000,000,000',
#    'LIST_SHRS': '30,000,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '000680',
#    'ISU_ABBRV': 'LS네트웍스',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '2,835',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '15',
#    'FLUC_RT': '0.53',
#    'TDD_OPNPRC': '2,855',
#    'TDD_HGPRC': '2,855',
#    'TDD_LWPRC': '2,820',
#    'ACC_TRDVOL': '40,984',
#    'ACC_TRDVAL': '116,049,240',
#    'MKTCAP': '223,406,550,360',
#    'LIST_SHRS': '78,803,016',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '229640',
#    'ISU_ABBRV': 'LS전선아시아',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '7,820',
#    'FLUC_TP_CD': '3',
#    'CMPPREVDD_PRC': '0',
#    'FLUC_RT': '0.00',
#    'TDD_OPNPRC': '7,890',
#    'TDD_HGPRC': '7,890',
#    'TDD_LWPRC': '7,780',
#    'ACC_TRDVOL': '141,988',
#    'ACC_TRDVAL': '1,109,278,300',
#    'MKTCAP': '239,486,553,780',
#    'LIST_SHRS': '30,624,879',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '023150',
#    'ISU_ABBRV': 'MH에탄올',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '8,540',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-170',
#    'FLUC_RT': '-1.95',
#    'TDD_OPNPRC': '8,710',
#    'TDD_HGPRC': '8,710',
#    'TDD_LWPRC': '8,510',
#    'ACC_TRDVOL': '82,007',
#    'ACC_TRDVAL': '702,808,020',
#    'MKTCAP': '63,012,612,040',
#    'LIST_SHRS': '7,378,526',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '035420',
#    'ISU_ABBRV': 'NAVER',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '378,500',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '1,500',
#    'FLUC_RT': '0.40',
#    'TDD_OPNPRC': '375,500',
#    'TDD_HGPRC': '379,000',
#    'TDD_LWPRC': '372,000',
#    'ACC_TRDVOL': '547,402',
#    'ACC_TRDVAL': '205,901,007,000',
#    'MKTCAP': '62,173,695,007,500',
#    'LIST_SHRS': '164,263,395',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '181710',
#    'ISU_ABBRV': 'NHN',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '71,600',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-900',
#    'FLUC_RT': '-1.24',
#    'TDD_OPNPRC': '72,600',
#    'TDD_HGPRC': '72,600',
#    'TDD_LWPRC': '71,400',
#    'ACC_TRDVOL': '52,887',
#    'ACC_TRDVAL': '3,793,385,200',
#    'MKTCAP': '1,400,855,790,000',
#    'LIST_SHRS': '19,565,025',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '005940',
#    'ISU_ABBRV': 'NH투자증권',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '11,500',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-150',
#    'FLUC_RT': '-1.29',
#    'TDD_OPNPRC': '11,700',
#    'TDD_HGPRC': '11,750',
#    'TDD_LWPRC': '11,450',
#    'ACC_TRDVOL': '898,747',
#    'ACC_TRDVAL': '10,397,513,300',
#    'MKTCAP': '3,236,202,200,500',
#    'LIST_SHRS': '281,408,887',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '005945',
#    'ISU_ABBRV': 'NH투자증권우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '9,660',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '120',
#    'FLUC_RT': '1.26',
#    'TDD_OPNPRC': '9,550',
#    'TDD_HGPRC': '9,700',
#    'TDD_LWPRC': '9,550',
#    'ACC_TRDVOL': '207,052',
#    'ACC_TRDVAL': '1,999,349,980',
#    'MKTCAP': '182,293,550,880',
#    'LIST_SHRS': '18,870,968',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '338100',
#    'ISU_ABBRV': 'NH프라임리츠',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '4,385',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-10',
#    'FLUC_RT': '-0.23',
#    'TDD_OPNPRC': '4,395',
#    'TDD_HGPRC': '4,400',
#    'TDD_LWPRC': '4,355',
#    'ACC_TRDVOL': '62,052',
#    'ACC_TRDVAL': '271,805,710',
#    'MKTCAP': '81,824,100,000',
#    'LIST_SHRS': '18,660,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '034310',
#    'ISU_ABBRV': 'NICE',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '17,350',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '250',
#    'FLUC_RT': '1.46',
#    'TDD_OPNPRC': '17,200',
#    'TDD_HGPRC': '17,350',
#    'TDD_LWPRC': '17,150',
#    'ACC_TRDVOL': '88,062',
#    'ACC_TRDVAL': '1,519,133,600',
#    'MKTCAP': '657,257,905,000',
#    'LIST_SHRS': '37,882,300',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '008260',
#    'ISU_ABBRV': 'NI스틸',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '3,505',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-105',
#    'FLUC_RT': '-2.91',
#    'TDD_OPNPRC': '3,610',
#    'TDD_HGPRC': '3,615',
#    'TDD_LWPRC': '3,430',
#    'ACC_TRDVOL': '580,484',
#    'ACC_TRDVAL': '2,036,068,525',
#    'MKTCAP': '100,243,410,085',
#    'LIST_SHRS': '28,600,117',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '004250',
#    'ISU_ABBRV': 'NPC',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '4,250',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '75',
#    'FLUC_RT': '1.80',
#    'TDD_OPNPRC': '4,175',
#    'TDD_HGPRC': '4,295',
#    'TDD_LWPRC': '4,160',
#    'ACC_TRDVOL': '216,437',
#    'ACC_TRDVAL': '916,963,290',
#    'MKTCAP': '156,060,000,000',
#    'LIST_SHRS': '36,720,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '004255',
#    'ISU_ABBRV': 'NPC우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '2,345',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '25',
#    'FLUC_RT': '1.08',
#    'TDD_OPNPRC': '2,335',
#    'TDD_HGPRC': '2,345',
#    'TDD_LWPRC': '2,330',
#    'ACC_TRDVOL': '7,895',
#    'ACC_TRDVAL': '18,463,645',
#    'MKTCAP': '12,381,600,000',
#    'LIST_SHRS': '5,280,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '010060',
#    'ISU_ABBRV': 'OCI',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '119,000',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-2,500',
#    'FLUC_RT': '-2.06',
#    'TDD_OPNPRC': '123,000',
#    'TDD_HGPRC': '123,500',
#    'TDD_LWPRC': '117,500',
#    'ACC_TRDVOL': '256,358',
#    'ACC_TRDVAL': '30,565,083,000',
#    'MKTCAP': '2,838,075,149,000',
#    'LIST_SHRS': '23,849,371',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '005490',
#    'ISU_ABBRV': 'POSCO',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '318,500',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-1,500',
#    'FLUC_RT': '-0.47',
#    'TDD_OPNPRC': '320,500',
#    'TDD_HGPRC': '323,000',
#    'TDD_LWPRC': '314,000',
#    'ACC_TRDVOL': '458,156',
#    'ACC_TRDVAL': '145,643,910,396',
#    'MKTCAP': '27,769,006,947,500',
#    'LIST_SHRS': '87,186,835',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '010950',
#    'ISU_ABBRV': 'S-Oil',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '80,300',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-900',
#    'FLUC_RT': '-1.11',
#    'TDD_OPNPRC': '81,200',
#    'TDD_HGPRC': '81,200',
#    'TDD_LWPRC': '80,200',
#    'ACC_TRDVOL': '271,753',
#    'ACC_TRDVAL': '21,866,627,100',
#    'MKTCAP': '9,040,398,197,600',
#    'LIST_SHRS': '112,582,792',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '010955',
#    'ISU_ABBRV': 'S-Oil우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '46,000',
#    'FLUC_TP_CD': '3',
#    'CMPPREVDD_PRC': '0',
#    'FLUC_RT': '0.00',
#    'TDD_OPNPRC': '45,900',
#    'TDD_HGPRC': '46,450',
#    'TDD_LWPRC': '45,700',
#    'ACC_TRDVOL': '5,745',
#    'ACC_TRDVAL': '263,391,050',
#    'MKTCAP': '185,008,642,000',
#    'LIST_SHRS': '4,021,927',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '034120',
#    'ISU_ABBRV': 'SBS',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '22,650',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-50',
#    'FLUC_RT': '-0.22',
#    'TDD_OPNPRC': '23,200',
#    'TDD_HGPRC': '23,250',
#    'TDD_LWPRC': '22,400',
#    'ACC_TRDVOL': '214,797',
#    'ACC_TRDVAL': '4,891,070,750',
#    'MKTCAP': '413,420,982,300',
#    'LIST_SHRS': '18,252,582',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '101060',
#    'ISU_ABBRV': 'SBS미디어홀딩스',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '2,025',
#    'FLUC_TP_CD': '3',
#    'CMPPREVDD_PRC': '0',
#    'FLUC_RT': '0.00',
#    'TDD_OPNPRC': '1,960',
#    'TDD_HGPRC': '2,070',
#    'TDD_LWPRC': '1,945',
#    'ACC_TRDVOL': '1,101,663',
#    'ACC_TRDVAL': '2,209,060,075',
#    'MKTCAP': '283,289,784,750',
#    'LIST_SHRS': '139,896,190',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '005090',
#    'ISU_ABBRV': 'SGC에너지',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '40,050',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '450',
#    'FLUC_RT': '1.14',
#    'TDD_OPNPRC': '39,600',
#    'TDD_HGPRC': '40,550',
#    'TDD_LWPRC': '39,550',
#    'ACC_TRDVOL': '83,988',
#    'ACC_TRDVAL': '3,363,540,650',
#    'MKTCAP': '587,814,010,200',
#    'LIST_SHRS': '14,677,004',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '004060',
#    'ISU_ABBRV': 'SG세계물산',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '726',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-17',
#    'FLUC_RT': '-2.29',
#    'TDD_OPNPRC': '745',
#    'TDD_HGPRC': '749',
#    'TDD_LWPRC': '724',
#    'ACC_TRDVOL': '2,499,663',
#    'ACC_TRDVAL': '1,830,262,044',
#    'MKTCAP': '146,960,520,960',
#    'LIST_SHRS': '202,424,960',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '001380',
#    'ISU_ABBRV': 'SG충방',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '3,175',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-25',
#    'FLUC_RT': '-0.78',
#    'TDD_OPNPRC': '3,160',
#    'TDD_HGPRC': '3,220',
#    'TDD_LWPRC': '3,095',
#    'ACC_TRDVOL': '4,406,121',
#    'ACC_TRDVAL': '13,883,819,945',
#    'MKTCAP': '142,761,154,025',
#    'LIST_SHRS': '44,964,143',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '002360',
#    'ISU_ABBRV': 'SH에너지화학',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '936',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-4',
#    'FLUC_RT': '-0.43',
#    'TDD_OPNPRC': '946',
#    'TDD_HGPRC': '948',
#    'TDD_LWPRC': '932',
#    'ACC_TRDVOL': '705,821',
#    'ACC_TRDVAL': '661,533,160',
#    'MKTCAP': '104,021,171,280',
#    'LIST_SHRS': '111,133,730',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '009160',
#    'ISU_ABBRV': 'SIMPAC',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '3,235',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-5',
#    'FLUC_RT': '-0.15',
#    'TDD_OPNPRC': '3,270',
#    'TDD_HGPRC': '3,270',
#    'TDD_LWPRC': '3,185',
#    'ACC_TRDVOL': '54,811',
#    'ACC_TRDVAL': '176,940,240',
#    'MKTCAP': '211,664,484,260',
#    'LIST_SHRS': '65,429,516',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '123700',
#    'ISU_ABBRV': 'SJM',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '4,250',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '155',
#    'FLUC_RT': '3.79',
#    'TDD_OPNPRC': '4,095',
#    'TDD_HGPRC': '4,600',
#    'TDD_LWPRC': '4,070',
#    'ACC_TRDVOL': '295,776',
#    'ACC_TRDVAL': '1,264,617,405',
#    'MKTCAP': '66,320,816,500',
#    'LIST_SHRS': '15,604,898',
#    'MKT_ID': 'STK'},
# ...
#    'TDD_HGPRC': '96,200',
#    'TDD_LWPRC': '94,900',
#    'ACC_TRDVOL': '12,603',
#    'ACC_TRDVAL': '1,203,885,500',
#    'MKTCAP': '231,944,192,500',
#    'LIST_SHRS': '2,428,735',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '005385',
#    'ISU_ABBRV': '현대차우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '101,500',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '1,500',
#    'FLUC_RT': '1.50',
#    'TDD_OPNPRC': '100,500',
#    'TDD_HGPRC': '102,000',
#    'TDD_LWPRC': '100,500',
#    'ACC_TRDVOL': '54,976',
#    'ACC_TRDVAL': '5,567,502,500',
#    'MKTCAP': '2,472,203,527,500',
#    'LIST_SHRS': '24,356,685',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '001500',
#    'ISU_ABBRV': '현대차증권',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '13,000',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-50',
#    'FLUC_RT': '-0.38',
#    'TDD_OPNPRC': '13,300',
#    'TDD_HGPRC': '13,350',
#    'TDD_LWPRC': '12,900',
#    'ACC_TRDVOL': '148,997',
#    'ACC_TRDVAL': '1,961,269,750',
#    'MKTCAP': '390,612,430,000',
#    'LIST_SHRS': '30,047,110',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '227840',
#    'ISU_ABBRV': '현대코퍼레이션홀딩스',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '14,500',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-50',
#    'FLUC_RT': '-0.34',
#    'TDD_OPNPRC': '14,550',
#    'TDD_HGPRC': '14,650',
#    'TDD_LWPRC': '14,350',
#    'ACC_TRDVOL': '101,611',
#    'ACC_TRDVAL': '1,466,608,150',
#    'MKTCAP': '131,962,122,000',
#    'LIST_SHRS': '9,100,836',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '126560',
#    'ISU_ABBRV': '현대퓨처넷',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '4,795',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '5',
#    'FLUC_RT': '0.10',
#    'TDD_OPNPRC': '4,980',
#    'TDD_HGPRC': '5,080',
#    'TDD_LWPRC': '4,790',
#    'ACC_TRDVOL': '3,114,158',
#    'ACC_TRDVAL': '15,407,914,865',
#    'MKTCAP': '541,243,277,820',
#    'LIST_SHRS': '112,876,596',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '001450',
#    'ISU_ABBRV': '현대해상',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '24,000',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-500',
#    'FLUC_RT': '-2.04',
#    'TDD_OPNPRC': '24,550',
#    'TDD_HGPRC': '24,700',
#    'TDD_LWPRC': '23,950',
#    'ACC_TRDVOL': '362,101',
#    'ACC_TRDVAL': '8,793,128,750',
#    'MKTCAP': '2,145,600,000,000',
#    'LIST_SHRS': '89,400,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '057050',
#    'ISU_ABBRV': '현대홈쇼핑',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '81,300',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '400',
#    'FLUC_RT': '0.49',
#    'TDD_OPNPRC': '81,000',
#    'TDD_HGPRC': '81,900',
#    'TDD_LWPRC': '80,600',
#    'ACC_TRDVOL': '33,302',
#    'ACC_TRDVAL': '2,710,710,600',
#    'MKTCAP': '975,600,000,000',
#    'LIST_SHRS': '12,000,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '093240',
#    'ISU_ABBRV': '형지엘리트',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '4,355',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '25',
#    'FLUC_RT': '0.58',
#    'TDD_OPNPRC': '4,290',
#    'TDD_HGPRC': '4,380',
#    'TDD_LWPRC': '4,150',
#    'ACC_TRDVOL': '1,384,319',
#    'ACC_TRDVAL': '5,896,931,250',
#    'MKTCAP': '135,679,145,290',
#    'LIST_SHRS': '31,154,798',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '003010',
#    'ISU_ABBRV': '혜인',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '7,490',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-40',
#    'FLUC_RT': '-0.53',
#    'TDD_OPNPRC': '7,510',
#    'TDD_HGPRC': '7,610',
#    'TDD_LWPRC': '7,270',
#    'ACC_TRDVOL': '1,609,782',
#    'ACC_TRDVAL': '11,959,190,850',
#    'MKTCAP': '95,218,475,030',
#    'LIST_SHRS': '12,712,747',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '111110',
#    'ISU_ABBRV': '호전실업',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '10,150',
#    'FLUC_TP_CD': '3',
#    'CMPPREVDD_PRC': '0',
#    'FLUC_RT': '0.00',
#    'TDD_OPNPRC': '10,150',
#    'TDD_HGPRC': '10,150',
#    'TDD_LWPRC': '10,050',
#    'ACC_TRDVOL': '35,809',
#    'ACC_TRDVAL': '360,998,850',
#    'MKTCAP': '81,200,000,000',
#    'LIST_SHRS': '8,000,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '008770',
#    'ISU_ABBRV': '호텔신라',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '85,900',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-1,000',
#    'FLUC_RT': '-1.15',
#    'TDD_OPNPRC': '87,500',
#    'TDD_HGPRC': '87,800',
#    'TDD_LWPRC': '85,500',
#    'ACC_TRDVOL': '646,621',
#    'ACC_TRDVAL': '56,011,060,200',
#    'MKTCAP': '3,371,413,593,900',
#    'LIST_SHRS': '39,248,121',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '008775',
#    'ISU_ABBRV': '호텔신라우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '83,500',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-300',
#    'FLUC_RT': '-0.36',
#    'TDD_OPNPRC': '84,000',
#    'TDD_HGPRC': '84,400',
#    'TDD_LWPRC': '83,400',
#    'ACC_TRDVOL': '4,969',
#    'ACC_TRDVAL': '415,418,100',
#    'MKTCAP': '62,781,896,500',
#    'LIST_SHRS': '751,879',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '002460',
#    'ISU_ABBRV': '화성산업',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '12,200',
#    'FLUC_TP_CD': '3',
#    'CMPPREVDD_PRC': '0',
#    'FLUC_RT': '0.00',
#    'TDD_OPNPRC': '12,300',
#    'TDD_HGPRC': '12,350',
#    'TDD_LWPRC': '12,100',
#    'ACC_TRDVOL': '54,205',
#    'ACC_TRDVAL': '662,530,600',
#    'MKTCAP': '151,899,760,000',
#    'LIST_SHRS': '12,450,800',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '378850',
#    'ISU_ABBRV': '화승알앤에이',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '5,490',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-70',
#    'FLUC_RT': '-1.26',
#    'TDD_OPNPRC': '5,560',
#    'TDD_HGPRC': '5,620',
#    'TDD_LWPRC': '5,450',
#    'ACC_TRDVOL': '145,666',
#    'ACC_TRDVAL': '801,613,480',
#    'MKTCAP': '104,274,990,270',
#    'LIST_SHRS': '18,993,623',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '241590',
#    'ISU_ABBRV': '화승엔터프라이즈',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '17,950',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-350',
#    'FLUC_RT': '-1.91',
#    'TDD_OPNPRC': '18,100',
#    'TDD_HGPRC': '18,600',
#    'TDD_LWPRC': '17,850',
#    'ACC_TRDVOL': '279,380',
#    'ACC_TRDVAL': '5,083,664,800',
#    'MKTCAP': '1,086,790,558,250',
#    'LIST_SHRS': '60,545,435',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '006060',
#    'ISU_ABBRV': '화승인더',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '7,680',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-100',
#    'FLUC_RT': '-1.29',
#    'TDD_OPNPRC': '7,790',
#    'TDD_HGPRC': '7,820',
#    'TDD_LWPRC': '7,640',
#    'ACC_TRDVOL': '428,090',
#    'ACC_TRDVAL': '3,298,737,810',
#    'MKTCAP': '424,857,600,000',
#    'LIST_SHRS': '55,320,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '013520',
#    'ISU_ABBRV': '화승코퍼레이션',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '1,765',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-40',
#    'FLUC_RT': '-2.22',
#    'TDD_OPNPRC': '1,815',
#    'TDD_HGPRC': '1,820',
#    'TDD_LWPRC': '1,760',
#    'ACC_TRDVOL': '372,317',
#    'ACC_TRDVAL': '662,440,900',
#    'MKTCAP': '88,340,459,780',
#    'LIST_SHRS': '50,051,252',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '010690',
#    'ISU_ABBRV': '화신',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '4,855',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-45',
#    'FLUC_RT': '-0.92',
#    'TDD_OPNPRC': '4,905',
#    'TDD_HGPRC': '4,935',
#    'TDD_LWPRC': '4,810',
#    'ACC_TRDVOL': '193,429',
#    'ACC_TRDVAL': '939,084,690',
#    'MKTCAP': '169,538,590,550',
#    'LIST_SHRS': '34,920,410',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '133820',
#    'ISU_ABBRV': '화인베스틸',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '2,615',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-20',
#    'FLUC_RT': '-0.76',
#    'TDD_OPNPRC': '2,665',
#    'TDD_HGPRC': '2,670',
#    'TDD_LWPRC': '2,590',
#    'ACC_TRDVOL': '188,257',
#    'ACC_TRDVAL': '491,942,085',
#    'MKTCAP': '77,273,250,000',
#    'LIST_SHRS': '29,550,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '010660',
#    'ISU_ABBRV': '화천기계',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '2,550',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-15',
#    'FLUC_RT': '-0.58',
#    'TDD_OPNPRC': '2,565',
#    'TDD_HGPRC': '2,575',
#    'TDD_LWPRC': '2,535',
#    'ACC_TRDVOL': '130,388',
#    'ACC_TRDVAL': '332,807,525',
#    'MKTCAP': '56,100,000,000',
#    'LIST_SHRS': '22,000,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '000850',
#    'ISU_ABBRV': '화천기공',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '34,500',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-150',
#    'FLUC_RT': '-0.43',
#    'TDD_OPNPRC': '34,650',
#    'TDD_HGPRC': '35,000',
#    'TDD_LWPRC': '34,150',
#    'ACC_TRDVOL': '7,596',
#    'ACC_TRDVAL': '261,883,450',
#    'MKTCAP': '75,900,000,000',
#    'LIST_SHRS': '2,200,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '016580',
#    'ISU_ABBRV': '환인제약',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '18,100',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '100',
#    'FLUC_RT': '0.56',
#    'TDD_OPNPRC': '18,100',
#    'TDD_HGPRC': '18,150',
#    'TDD_LWPRC': '18,000',
#    'ACC_TRDVOL': '32,396',
#    'ACC_TRDVAL': '584,874,200',
#    'MKTCAP': '336,661,267,000',
#    'LIST_SHRS': '18,600,070',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '032560',
#    'ISU_ABBRV': '황금에스티',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '8,490',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-70',
#    'FLUC_RT': '-0.82',
#    'TDD_OPNPRC': '8,560',
#    'TDD_HGPRC': '8,650',
#    'TDD_LWPRC': '8,450',
#    'ACC_TRDVOL': '65,086',
#    'ACC_TRDVAL': '553,823,670',
#    'MKTCAP': '118,860,000,000',
#    'LIST_SHRS': '14,000,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '004800',
#    'ISU_ABBRV': '효성',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '87,500',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-1,400',
#    'FLUC_RT': '-1.57',
#    'TDD_OPNPRC': '89,100',
#    'TDD_HGPRC': '89,800',
#    'TDD_LWPRC': '87,000',
#    'ACC_TRDVOL': '87,318',
#    'ACC_TRDVAL': '7,692,782,900',
#    'MKTCAP': '1,843,714,687,500',
#    'LIST_SHRS': '21,071,025',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '094280',
#    'ISU_ABBRV': '효성ITX',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '19,900',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-300',
#    'FLUC_RT': '-1.49',
#    'TDD_OPNPRC': '20,250',
#    'TDD_HGPRC': '20,250',
#    'TDD_LWPRC': '19,700',
#    'ACC_TRDVOL': '33,292',
#    'ACC_TRDVAL': '663,193,350',
#    'MKTCAP': '230,008,180,000',
#    'LIST_SHRS': '11,558,200',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '298040',
#    'ISU_ABBRV': '효성중공업',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '75,800',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-2,600',
#    'FLUC_RT': '-3.32',
#    'TDD_OPNPRC': '78,400',
#    'TDD_HGPRC': '78,900',
#    'TDD_LWPRC': '75,700',
#    'ACC_TRDVOL': '120,220',
#    'ACC_TRDVAL': '9,203,266,200',
#    'MKTCAP': '706,800,738,400',
#    'LIST_SHRS': '9,324,548',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '298050',
#    'ISU_ABBRV': '효성첨단소재',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '371,500',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-9,000',
#    'FLUC_RT': '-2.37',
#    'TDD_OPNPRC': '382,000',
#    'TDD_HGPRC': '383,500',
#    'TDD_LWPRC': '371,000',
#    'ACC_TRDVOL': '89,486',
#    'ACC_TRDVAL': '33,521,855,500',
#    'MKTCAP': '1,664,300,682,000',
#    'LIST_SHRS': '4,479,948',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '298020',
#    'ISU_ABBRV': '효성티앤씨',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '558,000',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-15,000',
#    'FLUC_RT': '-2.62',
#    'TDD_OPNPRC': '570,000',
#    'TDD_HGPRC': '580,000',
#    'TDD_LWPRC': '554,000',
#    'ACC_TRDVOL': '66,311',
#    'ACC_TRDVAL': '37,578,488,000',
#    'MKTCAP': '2,414,846,556,000',
#    'LIST_SHRS': '4,327,682',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '298000',
#    'ISU_ABBRV': '효성화학',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '298,000',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-11,000',
#    'FLUC_RT': '-3.56',
#    'TDD_OPNPRC': '309,000',
#    'TDD_HGPRC': '311,000',
#    'TDD_LWPRC': '296,000',
#    'ACC_TRDVOL': '87,837',
#    'ACC_TRDVAL': '26,426,512,500',
#    'MKTCAP': '950,657,548,000',
#    'LIST_SHRS': '3,190,126',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '093370',
#    'ISU_ABBRV': '후성',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '10,550',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '50',
#    'FLUC_RT': '0.48',
#    'TDD_OPNPRC': '10,550',
#    'TDD_HGPRC': '10,550',
#    'TDD_LWPRC': '10,400',
#    'ACC_TRDVOL': '489,664',
#    'ACC_TRDVAL': '5,130,417,750',
#    'MKTCAP': '977,001,940,450',
#    'LIST_SHRS': '92,606,819',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '081660',
#    'ISU_ABBRV': '휠라홀딩스',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '42,150',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-1,000',
#    'FLUC_RT': '-2.32',
#    'TDD_OPNPRC': '43,100',
#    'TDD_HGPRC': '43,150',
#    'TDD_LWPRC': '42,050',
#    'ACC_TRDVOL': '452,394',
#    'ACC_TRDVAL': '19,175,026,450',
#    'MKTCAP': '2,560,706,157,300',
#    'LIST_SHRS': '60,752,222',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '005870',
#    'ISU_ABBRV': '휴니드',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '8,610',
#    'FLUC_TP_CD': '3',
#    'CMPPREVDD_PRC': '0',
#    'FLUC_RT': '0.00',
#    'TDD_OPNPRC': '8,570',
#    'TDD_HGPRC': '8,770',
#    'TDD_LWPRC': '8,510',
#    'ACC_TRDVOL': '653,783',
#    'ACC_TRDVAL': '5,648,071,640',
#    'MKTCAP': '121,538,889,150',
#    'LIST_SHRS': '14,116,015',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '079980',
#    'ISU_ABBRV': '휴비스',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '8,750',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-80',
#    'FLUC_RT': '-0.91',
#    'TDD_OPNPRC': '8,900',
#    'TDD_HGPRC': '8,900',
#    'TDD_LWPRC': '8,720',
#    'ACC_TRDVOL': '219,748',
#    'ACC_TRDVAL': '1,936,470,510',
#    'MKTCAP': '301,875,000,000',
#    'LIST_SHRS': '34,500,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '005010',
#    'ISU_ABBRV': '휴스틸',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '10,700',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-250',
#    'FLUC_RT': '-2.28',
#    'TDD_OPNPRC': '11,050',
#    'TDD_HGPRC': '11,100',
#    'TDD_LWPRC': '10,450',
#    'ACC_TRDVOL': '146,382',
#    'ACC_TRDVAL': '1,562,465,950',
#    'MKTCAP': '81,551,847,600',
#    'LIST_SHRS': '7,621,668',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '069260',
#    'ISU_ABBRV': '휴켐스',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '22,200',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '400',
#    'FLUC_RT': '1.83',
#    'TDD_OPNPRC': '21,900',
#    'TDD_HGPRC': '22,300',
#    'TDD_LWPRC': '21,900',
#    'ACC_TRDVOL': '588,795',
#    'ACC_TRDVAL': '13,017,826,400',
#    'MKTCAP': '907,504,653,600',
#    'LIST_SHRS': '40,878,588',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '000540',
#    'ISU_ABBRV': '흥국화재',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '4,045',
#    'FLUC_TP_CD': '2',
#    'CMPPREVDD_PRC': '-60',
#    'FLUC_RT': '-1.46',
#    'TDD_OPNPRC': '4,065',
#    'TDD_HGPRC': '4,110',
#    'TDD_LWPRC': '4,015',
#    'ACC_TRDVOL': '146,461',
#    'ACC_TRDVAL': '592,756,330',
#    'MKTCAP': '259,861,499,025',
#    'LIST_SHRS': '64,242,645',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '000547',
#    'ISU_ABBRV': '흥국화재2우B',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '20,450',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '150',
#    'FLUC_RT': '0.74',
#    'TDD_OPNPRC': '19,950',
#    'TDD_HGPRC': '20,450',
#    'TDD_LWPRC': '19,950',
#    'ACC_TRDVOL': '642',
#    'ACC_TRDVAL': '12,891,150',
#    'MKTCAP': '3,141,120,000',
#    'LIST_SHRS': '153,600',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '000545',
#    'ISU_ABBRV': '흥국화재우',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '8,500',
#    'FLUC_TP_CD': '1',
#    'CMPPREVDD_PRC': '220',
#    'FLUC_RT': '2.66',
#    'TDD_OPNPRC': '8,380',
#    'TDD_HGPRC': '8,500',
#    'TDD_LWPRC': '8,210',
#    'ACC_TRDVOL': '15,298',
#    'ACC_TRDVAL': '128,426,490',
#    'MKTCAP': '6,528,000,000',
#    'LIST_SHRS': '768,000',
#    'MKT_ID': 'STK'},
#   {'ISU_SRT_CD': '003280',
#    'ISU_ABBRV': '흥아해운',
#    'MKT_NM': 'KOSPI',
#    'SECT_TP_NM': '',
#    'TDD_CLSPRC': '258',
#    'FLUC_TP_CD': '0',
#    'CMPPREVDD_PRC': '0',
#    'FLUC_RT': '0.00',
#    'TDD_OPNPRC': '0',
#    'TDD_HGPRC': '0',
#    'TDD_LWPRC': '0',
#    'ACC_TRDVOL': '0',
#    'ACC_TRDVAL': '0',
#    'MKTCAP': '30,117,000,222',
#    'LIST_SHRS': '116,732,559',
#    'MKT_ID': 'STK'}],
#  'CURRENT_DATETIME': '2021.05.03 PM 02:47:10'}

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-12e81a6ce3be> in <module>
# ----> 1 li.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
li = r.text.split(',')
